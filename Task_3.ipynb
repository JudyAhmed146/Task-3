# %%
contacts={"name_1":"Ahmed", "Number_1":"01019775666 ",

              "name_2":"Jana","Number_2":"01116748884",

                    "name_3":"Malak","Number_3":"01100005498"}
print(contacts["name_1"])
print(contacts["name_2"])
print(contacts["name_3"])
Contacts = input("Contacts =")

if Contacts== (contacts["name_1"]):

    print(contacts["Number_1"])

elif Contacts== (contacts["name_2"]):

    print(contacts["Number_2"])

elif Contacts== (contacts["name_3"]):

    print(contacts["Number_3"])
else:
        print("not found")

# %%
students_list=[{"name":"Ahmed",
                          "Grade":{"math":98,"english":100,"physics":91}},
               {"name":"Hala",
                          "Grade":{"math":100,"english":99,"physics":95}},
               {"name":"Malak",
                          "Grade":{"math":90,"english":96,"physics":97}}]
Avg_grade=(students_list[0]["Grade"]["math"]+students_list[0]["Grade"]["english"]+students_list[0]["Grade"]["physics"])/3
print(students_list[0]["name"])
print(int(Avg_grade))
Avg_grade=(students_list[1]["Grade"]["math"]+students_list[1]["Grade"]["english"]+students_list[1]["Grade"]["physics"])/3
print(students_list[1]["name"])
print(int(Avg_grade))
Avg_grade=(students_list[2]["Grade"]["math"]+students_list[2]["Grade"]["english"]+students_list[2]["Grade"]["physics"])/3
print(students_list[2]["name"])
print(int(Avg_grade))
# Out:
# Ahmed
# 96
# Hala
# 98
# Malak
# 94
